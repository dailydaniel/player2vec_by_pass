# %%
import statsbomb as sb
from tqdm import tqdm
import re
import random
import numpy as np
from math import sqrt
from collections import defaultdict, Counter
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from matplotlib import collections as mc

from scipy.spatial import distance
from math import pi

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import pickle

# %%
events = """19714.json 	Added 0 new games, updated 68 games. 	a month ago
	19715.json 	Added 0 new games, updated 115 games. 	a month ago
	19716.json 	Added 0 new games, updated 1 games. 	a month ago
	19717.json 	Added 0 new games, updated 115 games. 	a month ago
	19718.json 	Added 0 new games, updated 115 games. 	a month ago
	19719.json 	Added 0 new games, updated 115 games. 	a month ago
	19720.json 	Added 0 new games, updated 115 games. 	a month ago
	19722.json 	Added 0 new games, updated 115 games. 	a month ago
	19723.json 	Added 0 new games, updated 68 games. 	a month ago
	19724.json 	Added 0 new games, updated 115 games. 	a month ago
	19725.json 	Added 4 new games, updated 2 games. 	29 days ago
	19726.json 	Added 0 new games, updated 115 games. 	a month ago
	19727.json 	Added 0 new games, updated 115 games. 	a month ago
	19728.json 	Added 0 new games, updated 68 games. 	a month ago
	19730.json 	Added 0 new games, updated 115 games. 	a month ago
	19731.json 	Added 0 new games, updated 115 games. 	a month ago
	19732.json 	Added 0 new games, updated 115 games. 	a month ago
	19733.json 	Added 0 new games, updated 115 games. 	a month ago
	19734.json 	Added 1 new games, updated 0 games. 	15 days ago
	19735.json 	Added 0 new games, updated 1 games. 	2 days ago
	19736.json 	Added 2 new games, updated 0 games. 	28 days ago
	19738.json 	Added 4 new games, updated 2 games. 	29 days ago
	19739.json 	Added 3 new games, updated 0 games. 	a month ago
	19740.json 	Added 3 new games, updated 0 games. 	a month ago
	19741.json 	Added 3 new games, updated 0 games. 	a month ago
	19742.json 	Added 4 new games, updated 2 games. 	29 days ago
	19743.json 	Added 2 new games, updated 0 games. 	28 days ago
	19744.json 	Added 1 new games, updated 0 games. 	23 days ago
	19745.json 	Added 1 new games, updated 0 games. 	22 days ago
	19746.json 	Added 1 new games, updated 0 games. 	23 days ago
	19747.json 	Added 1 new games, updated 0 games. 	21 days ago
	19748.json 	Added 1 new games, updated 0 games. 	25 days ago
	19749.json 	Added 3 new games, updated 0 games. 	17 days ago
	19750.json 	Added 1 new games, updated 0 games. 	12 days ago
	19751.json 	Added 1 new games, updated 0 games. 	16 days ago
	19752.json 	Added 3 new games, updated 0 games. 	17 days ago
	19753.json 	Added 3 new games, updated 0 games. 	17 days ago
	19759.json 	Added 5 new games, updated 0 games. 	8 days ago
	19760.json 	Added 5 new games, updated 0 games. 	8 days ago
	19761.json 	Added 5 new games, updated 0 games. 	8 days ago
	19762.json 	Added 5 new games, updated 0 games. 	8 days ago
	19763.json 	Added 5 new games, updated 0 games. 	8 days ago
	19765.json 	Added 1 new games, updated 0 games. 	4 days ago
	19766.json 	Added 3 new games, updated 0 games. 	5 days ago
	19767.json 	Added 3 new games, updated 0 games. 	5 days ago
	19768.json 	Added 3 new games, updated 0 games. 	5 days ago
	7298.json 	Added 0 new games, updated 8 games. 	3 months ago
	7443.json 	Added 0 new games, updated 115 games. 	a month ago
	7444.json 	Added 0 new games, updated 115 games. 	a month ago
	7445.json 	Added 0 new games, updated 115 games. 	a month ago
	7456.json 	Added 0 new games, updated 115 games. 	a month ago
	7457.json 	Added 0 new games, updated 115 games. 	a month ago
	7471.json 	Added 0 new games, updated 115 games. 	a month ago
	7472.json 	Added 0 new games, updated 115 games. 	a month ago
	7473.json 	Added 0 new games, updated 68 games. 	a month ago
	7474.json 	Added 0 new games, updated 115 games. 	a month ago
	7475.json 	Added 0 new games, updated 115 games. 	a month ago
	7476.json 	Added 0 new games, updated 115 games. 	a month ago
	7477.json 	Added 0 new games, updated 68 games. 	a month ago
	7478.json 	Added 0 new games, updated 115 games. 	a month ago
	7479.json 	Added 0 new games, updated 115 games. 	a month ago
	7480.json 	Added 0 new games, updated 68 games. 	a month ago
	7482.json 	Added 0 new games, updated 115 games. 	a month ago
	7483.json 	Added 0 new games, updated 68 games. 	a month ago
	7484.json 	Added 0 new games, updated 115 games. 	a month ago
	7485.json 	Added 0 new games, updated 115 games. 	a month ago
	7486.json 	Added 0 new games, updated 115 games. 	a month ago
	7487.json 	Added 0 new games, updated 115 games. 	a month ago
	7490.json 	Added 0 new games, updated 115 games. 	a month ago
	7492.json 	Added 0 new games, updated 115 games. 	a month ago
	7493.json 	Added 4 new games, updated 2 games. 	29 days ago
	7494.json 	Added 0 new games, updated 68 games. 	a month ago
	7496.json 	Added 0 new games, updated 68 games. 	a month ago
	7497.json 	Added 0 new games, updated 115 games. 	a month ago
	7500.json 	Added 4 new games, updated 2 games. 	29 days ago
	7519.json 	Added 0 new games, updated 115 games. 	a month ago
	7520.json 	Added 0 new games, updated 115 games. 	a month ago
	7521.json 	Added 0 new games, updated 115 games. 	a month ago
	7522.json 	Added 0 new games, updated 115 games. 	a month ago
	7523.json 	Added 0 new games, updated 115 games. 	a month ago
	7524.json 	Added 0 new games, updated 115 games. 	a month ago
	7525.json 	Added 0 new games, updated 115 games. 	a month ago
	7529.json 	Added 0 new games, updated 68 games. 	a month ago
	7530.json 	Added 0 new games, updated 68 games. 	a month ago
	7531.json 	Added 0 new games, updated 68 games. 	a month ago
	7532.json 	Added 0 new games, updated 68 games. 	a month ago
	7533.json 	Added 0 new games, updated 68 games. 	a month ago
	7534.json 	Added 0 new games, updated 68 games. 	a month ago
	7535.json 	Added 0 new games, updated 68 games. 	a month ago
	7536.json 	Added 0 new games, updated 68 games. 	a month ago
	7537.json 	Added 0 new games, updated 68 games. 	a month ago
	7538.json 	Added 0 new games, updated 68 games. 	a month ago
	7539.json 	Added 0 new games, updated 68 games. 	a month ago
	7540.json 	Added 0 new games, updated 68 games. 	a month ago
	7541.json 	Added 0 new games, updated 68 games. 	a month ago
	7542.json 	Added 0 new games, updated 68 games. 	a month ago
	7543.json 	Added 0 new games, updated 68 games. 	a month ago
	7544.json 	Added 0 new games, updated 68 games. 	a month ago
	7545.json 	Added 0 new games, updated 68 games. 	a month ago
	7546.json 	Added 0 new games, updated 68 games. 	a month ago
	7547.json 	Added 0 new games, updated 68 games. 	a month ago
	7548.json 	Added 0 new games, updated 68 games. 	a month ago
	7549.json 	Added 0 new games, updated 68 games. 	a month ago
	7550.json 	Added 0 new games, updated 68 games. 	a month ago
	7551.json 	Added 0 new games, updated 68 games. 	a month ago
	7552.json 	Added 0 new games, updated 1 games. 	13 days ago
	7553.json 	Added 0 new games, updated 68 games. 	a month ago
	7554.json 	Added 0 new games, updated 68 games. 	a month ago
	7555.json 	Added 0 new games, updated 68 games. 	a month ago
	7556.json 	Added 0 new games, updated 68 games. 	a month ago
	7557.json 	Added 0 new games, updated 68 games. 	a month ago
	7558.json 	Added 0 new games, updated 68 games. 	a month ago
	7559.json 	Added 0 new games, updated 68 games. 	a month ago
	7560.json 	Added 0 new games, updated 68 games. 	a month ago
	7561.json 	Added 0 new games, updated 68 games. 	a month ago
	7562.json 	Added 0 new games, updated 68 games. 	a month ago
	7563.json 	Added 0 new games, updated 68 games. 	a month ago
	7564.json 	Added 0 new games, updated 68 games. 	a month ago
	7565.json 	Added 0 new games, updated 68 games. 	a month ago
	7566.json 	Added 0 new games, updated 68 games. 	a month ago
	7567.json 	Added 0 new games, updated 115 games. 	a month ago
	7568.json 	Added 0 new games, updated 115 games. 	a month ago
	7569.json 	Added 0 new games, updated 115 games. 	a month ago
	7570.json 	Added 0 new games, updated 68 games. 	a month ago
	7571.json 	Added 0 new games, updated 68 games. 	a month ago
	7572.json 	Added 0 new games, updated 68 games. 	a month ago
	7576.json 	Added 0 new games, updated 68 games. 	a month ago
	7577.json 	Added 0 new games, updated 115 games. 	a month ago
	7578.json 	Added 0 new games, updated 68 games. 	a month ago
	7579.json 	Added 0 new games, updated 68 games. 	a month ago
	7580.json 	Added 0 new games, updated 68 games. 	a month ago
	7581.json 	Added 0 new games, updated 68 games. 	a month ago
	7582.json 	Added 0 new games, updated 68 games. 	a month ago
	7583.json 	Added 0 new games, updated 68 games. 	a month ago
	7584.json 	Added 0 new games, updated 68 games. 	a month ago
	7585.json 	Added 0 new games, updated 68 games. 	a month ago
	7586.json 	Added 0 new games, updated 68 games. 	a month ago
	8649.json 	Added 0 new games, updated 68 games. 	a month ago
	8650.json 	Added 0 new games, updated 68 games. 	a month ago
	8651.json 	Added 0 new games, updated 68 games. 	a month ago
	8652.json 	Added 0 new games, updated 68 games. 	a month ago
	8655.json 	Added 0 new games, updated 68 games. 	a month ago
	8656.json 	Added 0 new games, updated 68 games. 	a month ago
	8657.json 	Added 0 new games, updated 68 games. 	a month ago
	8658.json"""

events = re.findall(r'[0-9]+\.json', events)
events = [x[:-5] for x in events]
res = []
for i in tqdm(events):
    t = sb.Events(event_id=i)
    res.append((t.data[0]['team']['name'], t.data[1]['team']['name'], i))
    
teams = ['Iran', 'South Korea', 'Japan', 'Saudi Arabia', 'Australia', 
         'Tunisia', 'Nigeria', 'Morocco', 'Senegal', 'Egypt',
         'Mexico', 'Costa Rica', 'Panama',
         'Brazil', 'Uruguay', 'Argentina', 'Colombia', 'Peru',
         'France', 'Portugal', 'Germany', 'Serbia', 'Poland', 'England', 'Spain', 'Belgium', 'Iceland', 'Switzerland', 'Croatia', 'Denmark', 'Sweden', 'Russia']

res = [item for item in res if item[0] in teams or item[1] in teams]
# Out:
# 100%|██████████| 145/145 [01:08<00:00,  2.12it/s]

# %%
X = 120
Y = 90
def toCell(n=(8, 6), coords=(10.0, 10.0), normalized=False): # n = (8, 6) => 15
#     n = sqrt(X * Y / n)
#     nx = X / n[0]
#     ny = Y / n[1]
    nx, ny = n[0], n[1]
    nx = int(nx) 
    ny = int(ny)
    res = np.zeros((ny, nx))
    if normalized:
        coords = (coords[0] * X / nx, coords[1] * Y / ny)
    cury = int(coords[1] // (Y / ny))
    curx = int(coords[0] // (X / nx))
    cury = ny-1 if cury == ny else cury #
    curx = nx-1 if curx == nx else curx #
    res[cury][curx] = 1
    return res

def preproc(df, play_patterns, height_patterns, data_col, labels_col, types_col, X, Y, norm=True):
    df.under_pressure = df.under_pressure.apply(lambda x: 1 if x else 0)
    df.play_pattern = df.play_pattern.apply(lambda x: play_patterns[x])
    df.height = df.height.apply(lambda x: height_patterns[x] / len(height_patterns))
    df.pass_backheel = df.pass_backheel.apply(lambda x: 1 if x else 0)
    df.miscommunication = df.miscommunication.apply(lambda x: 1 if x else 0)
    df.through_ball = df.through_ball.apply(lambda x: 1 if x else 0)
    df.cross = df.cross.apply(lambda x: 1 if x else 0)
    df.cut_back = df.cut_back.apply(lambda x: 1 if x else 0)
    df.switch = df.switch.apply(lambda x: 1 if x else 0)
    df.shot_assist = df.shot_assist.apply(lambda x: 1 if x else 0)
    df.goal_assist = df.goal_assist.apply(lambda x: 1 if x else 0)
    if norm:
        df.start_location_x = df.start_location_x.apply(lambda x: x / X)
        df.start_location_y = df.start_location_x.apply(lambda x: x / Y)
        df.end_location_x = df.start_location_x.apply(lambda x: x / X)
        df.end_location_y = df.start_location_x.apply(lambda x: x / Y)
        df.length = df.length.apply(lambda x: x / X)
    return df[data_col], df[labels_col], df[types_col]

# %%
columns = ['timestamp', 'possession_team', 'player', 'play_pattern', 'duration', 
           'under_pressure', 'length', 'angle', 'height', 'pass_backheel', 
           'miscommunication', 'through_ball', 'cross', 'cut_back', 'switch', 'shot_assist', 
           'goal_assist', 'start_location_x', 'start_location_y', 'end_location_x', 
           'end_location_y']
# data_col = ['duration', 'under_pressure', 'length', 'angle', 'height', 'pass_backheel', 
#             'miscommunication', 'through_ball', 'cross', 'cut_back', 'switch', 'shot_assist', 
#             'goal_assist', 'start_location_x', 'start_location_y', 'end_location_x', 
#             'end_location_y']
data_col = ['start_location_x', 'start_location_y', 
            'end_location_x', 'end_location_y',
            'height', 'length', 'angle']
# data_col = ['play_pattern', 'duration', 
#             'under_pressure', 'length', 'angle', 'height', 'pass_backheel', 
#             'miscommunication', 'through_ball', 'cross', 'cut_back', 'switch', 'shot_assist', 
#             'goal_assist', 'start_location_x', 'start_location_y', 'end_location_x', 
#             'end_location_y']
# labels_col = ['play_pattern']
players_col = ['player']
types_col = ['play_pattern']
play_patterns = {'Regular Play': 0, 'From Corner': 1, 'From Free Kick': 2, 'From Throw In': 3, 
                 'Other': 4, 'From Counter': 5, 'From Goal Kick': 6, 'From Keeper': 7, 
                 'From Kick Off': 8}
height_patterns = {'Ground Pass': 0, 'Low Pass': 1, 'High Pass': 2}

data = pd.DataFrame(columns=data_col)
players = pd.DataFrame(columns=players_col)
types = pd.DataFrame(columns=types_col)

for match_id in tqdm([x[2] for x in res]): # cur_res
    match = sb.Events(event_id=match_id)
    df = match.get_dataframe(event_type='pass')[columns]
#     df = df[df.possession_team == team]
#     df = df.reset_index(drop=True)
    cur_data, cur_players, cur_types = preproc(df, play_patterns=play_patterns, 
                                               height_patterns=height_patterns, data_col=data_col, 
                                               labels_col=players_col, types_col=types_col, X=X, Y=Y)
    data = data.append(cur_data, ignore_index=True)
    players = players.append(cur_players, ignore_index=True)
    types = types.append(cur_types, ignore_index=True)
    
data = data.sample(frac=1)
ind = data.index
players = players.reindex(ind)
types = types.reindex(ind)

data = data.reset_index(drop=True)
players = players.reset_index(drop=True)
types = types.reset_index(drop=True)
# Out:
# 100%|██████████| 64/64 [01:10<00:00,  1.11s/it]

# %%
player_c = Counter()
all_players = [x[0] for x in players.values]
for player in all_players:
    player_c[player] += 1
MIN_P = 100
players_list = [key for key, val in player_c.items() if val >= MIN_P]

# %%
# players_list = list(set(all_players))

# %%
player2idx = {player: i for i, player in enumerate(players_list)}
idx2player = {val: key for key, val in player2idx.items()}

# %%
players = players.loc[players.player.isin(players_list)]
data = data.loc[data.index.isin(players.index)]
players = players.reset_index(drop=True)
data = data.reset_index(drop=True)

# %%
model = torch.load('data/Player2Vec.pth')

with open(, 'rb')

# %%
emb = Embedding(model, players_list, player2idx)

# %%
players_list[random.randint(0, len(players_list)-1)]
# Out:
# 'Gerard Piqué Bernabéu'

# %%
emb.most_common('Sergei Ignashevich')
# Out:
# [('Sergei Ignashevich', 1.0),
#  ('Ramin Rezaeian', 0.9915658235549927),
#  ('Robin Olsen', 0.9724604487419128),
#  ('Jordan Pickford', 0.9682353138923645),
#  ('Kléper Laveran Lima Ferreira', 0.9665459990501404),
#  ('Kasper Schmeichel', 0.9647150039672852),
#  ('Thibaut Courtois', 0.9636041522026062),
#  ('Néstor Fernando Muslera Micol', 0.9527627229690552),
#  ('Danijel Subašić', 0.9448751211166382),
#  ('Hugo Lloris', 0.9338892698287964)]

# %%
emb.most_common('Aleksandr Golovin')
# Out:
# [('Aleksandr Golovin', 1.0),
#  ('Yasir Gharsan Al Shahrani', 0.922083854675293),
#  ('José Paulo Bezzera Maciel Júnior', 0.8460330963134766),
#  ('Olivier Giroud', 0.8393037915229797),
#  ('Yuto Nagatomo', 0.8262684941291809),
#  ('Makoto Hasebe', 0.7864456176757812),
#  ('Mario Mandžukić', 0.7718320488929749),
#  ('Ivan Perišić', 0.7321248650550842),
#  ('Thomas Müller', 0.7067509889602661),
#  ('Marouane Fellaini-Bakkioui', 0.6853911280632019)]

# %%
emb.most_common('Cristiano Ronaldo dos Santos Aveiro')
# Out:
# [('Cristiano Ronaldo dos Santos Aveiro', 1.0),
#  ('Radamel Falcao García Zárate', 0.986106812953949),
#  ('Erick Javier Davis Grajales', 0.9845582842826843),
#  ('André Martín Carrillo Díaz', 0.9775140285491943),
#  ('Gylfi Þór Sigurðsson', 0.9607445001602173),
#  ('Sergej Milinković-Savić', 0.9544313549995422),
#  ('Artem Dzyuba', 0.9390392899513245),
#  ('Younès Belhanda', 0.930273175239563),
#  ('Mbark Boussoufa', 0.9116463661193848),
#  ('Thomas Müller', 0.8980507850646973)]

# %%
emb.most_common('Thibaut Courtois')
# Out:
# [('Thibaut Courtois', 1.0),
#  ('Néstor Fernando Muslera Micol', 0.9749547243118286),
#  ('Sergei Ignashevich', 0.9636041522026062),
#  ('Kléper Laveran Lima Ferreira', 0.9580315351486206),
#  ('Jordan Pickford', 0.9576630592346191),
#  ('William Troost-Ekong', 0.9550248980522156),
#  ('Ramin Rezaeian', 0.942228376865387),
#  ('Yann Sommer', 0.9353172183036804),
#  ('Robin Olsen', 0.9311882853507996),
#  ('Davinson Sánchez Mina', 0.9210401177406311)]

# %%
def plot_radar(players_names, embed, yticks=[0.02, 0.04, 0.08], ytsize=7, ylim=0.1, subplot=111):
    players_dict = {}
    for name in players_names:
        players_dict[name] = [x if x > 0 else 0.0 for x in list(embed[name])]
        
    players = list(players_dict.keys())
    df = pd.DataFrame({
    'player': players
    })
    for i in range(len(list(players_dict.values())[0])):
        df[str(i)] = [players_dict[key][i] for key in players]
    
    categories=list(df)[1:]
    N = len(categories)
    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    
    ax = plt.subplot(subplot, polar=True)
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles[:-1], categories)
    
    ax.set_rlabel_position(0)
    plt.yticks(yticks, [str(x) for x in yticks], color="grey", size=ytsize)
    plt.ylim(0, ylim)
    
    for i in range(df.index.size):
        values=df.loc[i].drop(df.columns[0]).values.flatten().tolist()
        values += values[:1]
        ax.plot(angles, values, linewidth=1, linestyle='solid', label=df[df.columns[0]].tolist()[i])
        ax.fill(angles, values, 'b', alpha=0.1)
        
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    plt.show()

# %%
# plot_radar(df)
plot_radar(['Aleksandr Golovin', 'Sergej Milinković-Savić'], emb, [0.02, 0.04, 0.08], 7, 0.1)

# %%
player = 'Gerard Piqué Bernabéu'
mc = emb.most_common(player, 5)
names = [name for name, val in mc]
mc
# Out:
# [('Gerard Piqué Bernabéu', 1.0),
#  ('Nicolás Hernán Otamendi', 0.992576539516449),
#  ('Thiago Emiliano da Silva', 0.9694604873657227),
#  ('Sergio Ramos García', 0.9536228179931641),
#  ('William Silva de Carvalho', 0.8295530080795288)]

# %%
for name in names:
    plot_radar([name], emb)

# %%
positions = defaultdict(list)
for match_id in tqdm([x[2] for x in res]):
    match = sb.Events(event_id=match_id)
    for info in match.data[0]['tactics']['lineup']:
        positions[info['player']['name']].append(info['position']['name'])
    
    for info in match.data[1]['tactics']['lineup']:
        positions[info['player']['name']].append(info['position']['name'])
# Out:
# 100%|██████████| 64/64 [00:59<00:00,  1.07it/s]

# %%
positions = {key: Counter(val).most_common(1)[0][0] for key, val in positions.items()}

# %%
pos_list = list(set(list(positions.values())))
pos2id = {pos: i for i, pos in enumerate(pos_list)}

# %%
pos_classes = {0: ['Right Midfield', 'Right Wing', 'Left Wing', 'Left Midfield', 
                   'Left Attacking Midfield', 'Right Attacking Midfield'],
               1: ['Right Center Midfield', 'Left Defensive Midfield', 'Center Attacking Midfield',
                   'Right Defensive Midfield', 'Center Midfield', 'Center Defensive Midfield',
                   'Left Center Midfield'],
               2: ['Left Wing Back', 'Right Wing Back', 'Right Back', 'Left Back'],
               3: ['Right Center Back', 'Left Center Back', 'Center Back'],
               4: ['Goalkeeper'],
               5: ['Left Center Forward', 'Right Center Forward', 'Center Forward', 
                   'Secondary Striker']
              }
pos2id_classes = {}
for key, val in pos_classes.items():
    for v in val:
        pos2id_classes[v] = key

# %%
positions_id = {key: pos2id_classes[val] for key, val in positions.items()}

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=1000)

vectors = [emb[name] for name in players_list]

tsne_results = tsne.fit_transform(vectors)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 250 samples in 0.000s...
# [t-SNE] Computed neighbors for 250 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 250 / 250
# [t-SNE] Mean sigma: 0.037863
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.198792
# [t-SNE] Error after 900 iterations: 0.466437

# %%
pca = PCA(n_components=2)

vectors = [emb[name] for name in players_list]

pca_results = pca.fit_transform(vectors)

# %%
theta = 2 * np.pi * np.random.rand(len(list(pos_classes.keys())))
np.random.shuffle(theta)
colors = [theta[x] for x in [positions_id[name] for name in players_list]] 

fig, ax = plt.subplots(figsize=(25, 15))
ax.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5, c=colors, s=[100]*len(tsne_results))
plt.title('t-SNE')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 15))
ax.scatter(pca_results[:, 0], pca_results[:, 1], alpha=0.5, c=colors, s=[100]*len(pca_results))
plt.title('t-SNE')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.scatter(list(pos_classes.keys()), [5 for i in range(len(list(pos_classes.keys())))], 
           alpha=0.5, c=theta, s=[1000] * len(theta))
plt.show()
print()

# %%
teams = defaultdict(list)
for match_id in tqdm([x[2] for x in res]):
    match = sb.Events(event_id=match_id)
    
    team = match.data[0]['possession_team']['name']
    for player in match.data[0]['tactics']['lineup']:
        teams[team].append(player['player']['name'])
    
    team = match.data[1]['possession_team']['name']
    for player in match.data[0]['tactics']['lineup']:
        teams[team].append(player['player']['name'])
# Out:
# 100%|██████████| 64/64 [00:43<00:00,  1.46it/s]

# %%
teams = {key: list(set(val)) for key, val in teams.items()}

# %%
teams_vec = {key: sum([emb[x] for x in val if x in players_list]) / len([emb[x] for x in val if x in players_list]) 
             for key, val in teams.items()}

# %%
teams_list = list(teams_vec.keys())

# %%
class TeamEmbedding(object):
    def __init__(self, teams):
        self.emb = teams
            
    def __getitem__(self, key):
        return self.emb[key]
    
    def dist(self, a, b, vec=False):
        if vec:
            return 1.0 - distance.cosine(a, b)
        else:
            return 1.0 - distance.cosine(self.emb[a], self.emb[b])
    
    def most_common(self, a, n=10, vec=False):
        dd = {key: self.dist(a, val, vec=True) for key, val in self.emb.items()} if vec else {key: self.dist(self.emb[a], val, vec=True) for key, val in self.emb.items()}
        return sorted(dd.items(), key=lambda x: -x[1])[:n]

# %%
team_emb = TeamEmbedding(teams_vec)

# %%
team_emb.most_common('Spain', 5)
# Out:
# [('Spain', 1.0),
#  ('Brazil', 0.8938555717468262),
#  ('Germany', 0.8632105588912964),
#  ('Belgium', 0.8203027844429016),
#  ('Saudi Arabia', 0.8156481385231018)]

# %%
team_emb.most_common('Russia', 5)
# Out:
# [('Russia', 1.0),
#  ('Sweden', 0.9642917513847351),
#  ('Colombia', 0.8837975263595581),
#  ('Iran', 0.8816269636154175),
#  ('Denmark', 0.8613367676734924)]

# %%
vectors = [team_emb[name] for name in teams_list]

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=1000)
tsne_results = tsne.fit_transform(vectors)

pca = PCA(n_components=2)
pca_results = pca.fit_transform(vectors)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 32 samples in 0.000s...
# [t-SNE] Computed neighbors for 32 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 32 / 32
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 43.839859
# [t-SNE] Error after 1000 iterations: 0.509427

# %%
colors = ['b'] * len(vectors) 

fig, ax = plt.subplots(figsize=(25, 15))
ax.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5, c=colors, s=[100]*len(tsne_results))
plt.title('t-SNE')
plt.xlabel('x')
plt.ylabel('y')

for i, team in enumerate(teams_list):
    ax.annotate(team, (tsne_results[i][0], tsne_results[i][1]))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 15))
ax.scatter(pca_results[:, 0], pca_results[:, 1], alpha=0.5, c=colors, s=[100]*len(pca_results))
plt.title('t-SNE')
plt.xlabel('x')
plt.ylabel('y')

for i, team in enumerate(teams_list):
    ax.annotate(team, (pca_results[i][0], pca_results[i][1]))

plt.show()

# %%
torch.save(model, 'data/Player2Vec.pth')

with open('data/player_emb.pickle', 'wb') as f:
    pickle.dump(emb, f)
    
with open('data/team_emb.pickle', 'wb') as f:
    pickle.dump(team_emb, f)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Pass2Vec. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
